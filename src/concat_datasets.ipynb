# %%
import numpy as np
import pandas as pd

# %%
import prepare_load_data, weather_utils.get_weather, weather_utils.process_weather, weather_utils.regions
# Out:
#   Cell In[4], line 1
#     import prepare_load_data, weather_utils\get_weather, process_weather, regions
#                                             ^
# SyntaxError: unexpected character after line continuation character
